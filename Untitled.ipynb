# %%
import pandas as pd
import json

# %%
full_program  = {
    "program": [
                {
                    "from": "9",
                    "to": "10.5",
                    "visit": "The Museum of Egyptian Antiquities",
                    "rating": "4.5",
                    "cost": "0.66"
                },
                {
                    "from": "10.5",
                    "to": "12.0",
                    "visit": "Aisha Fahmi Palace",
                    "rating": "5.0",
                    "cost": "0.66"
                },
                {
                    "from": "12.0",
                    "to": "13.0",
                    "visit": "Museum of Islamic Ceramics",
                    "rating": "3.0",
                    "cost": "0.66"
                },
                {
                    "from": "13.0",
                    "to": "14.25",
                    "visit": "Cairo Tower",
                    "rating": "4.0",
                    "cost": "0.66"
                },
                {
                    "from": "14.25",
                    "to": "14.7",
                    "visit": "House of the People Beit El-Umma Museum",
                    "rating": "4.5",
                    "cost": "0.66"
                },
                {
                    "from": "14.7",
                    "to": "16.7",
                    "visit": "Abdeen Palace Museum",
                    "rating": "4.0",
                    "cost": "0.66"
                },
                {
                    "from": "16.7",
                    "to": "17.7",
                    "visit": "National Geographic Society Museum",
                    "rating": "4.5",
                    "cost": "0.66"
                }
    ],
            "totalHours": 8.7,
            "totalMoney": 4.62
        }

# %%
full_input = {
    "programs_suggested": full_program,
    "nationality": "egyptian",
    "age": "adult",
    "index": 3
}

json.dumps(full_input)
# Out:
# '{"programs_suggested": {"program": [{"from": "9", "to": "10.5", "visit": "The Museum of Egyptian Antiquities", "rating": "4.5", "cost": "0.66"}, {"from": "10.5", "to": "12.0", "visit": "Aisha Fahmi Palace", "rating": "5.0", "cost": "0.66"}, {"from": "12.0", "to": "13.0", "visit": "Museum of Islamic Ceramics", "rating": "3.0", "cost": "0.66"}, {"from": "13.0", "to": "14.25", "visit": "Cairo Tower", "rating": "4.0", "cost": "0.66"}, {"from": "14.25", "to": "14.7", "visit": "House of the People Beit El-Umma Museum", "rating": "4.5", "cost": "0.66"}, {"from": "14.7", "to": "16.7", "visit": "Abdeen Palace Museum", "rating": "4.0", "cost": "0.66"}, {"from": "16.7", "to": "17.7", "visit": "National Geographic Society Museum", "rating": "4.5", "cost": "0.66"}], "totalHours": 8.7, "totalMoney": 4.62}, "nationality": "egyptian", "age": "adult", "index": 3}'

# %%
natinality age

# %%
json.dumps(full_program)
# Out:
# '{"program": [{"from": "9", "to": "10.5", "visit": "The Museum of Egyptian Antiquities", "rating": "4.5", "cost": "0.66"}, {"from": "10.5", "to": "12.0", "visit": "Aisha Fahmi Palace", "rating": "5.0", "cost": "0.66"}, {"from": "12.0", "to": "13.0", "visit": "Museum of Islamic Ceramics", "rating": "3.0", "cost": "0.66"}, {"from": "13.0", "to": "14.25", "visit": "Cairo Tower", "rating": "4.0", "cost": "0.66"}, {"from": "14.25", "to": "14.7", "visit": "House of the People Beit El-Umma Museum", "rating": "4.5", "cost": "0.66"}, {"from": "14.7", "to": "16.7", "visit": "Abdeen Palace Museum", "rating": "4.0", "cost": "0.66"}, {"from": "16.7", "to": "17.7", "visit": "National Geographic Society Museum", "rating": "4.5", "cost": "0.66"}], "totalHours": 8.7, "totalMoney": 4.62}'

# %%
program = full_program['program']

# %%
program
# Out:
# [{'from': '9',
#   'to': '10.5',
#   'visit': 'The Museum of Egyptian Antiquities',
#   'rating': '4.5',
#   'cost': '0.66'},
#  {'from': '10.5',
#   'to': '12.0',
#   'visit': 'Aisha Fahmi Palace',
#   'rating': '5.0',
#   'cost': '0.66'},
#  {'from': '12.0',
#   'to': '13.0',
#   'visit': 'Museum of Islamic Ceramics',
#   'rating': '3.0',
#   'cost': '0.66'},
#  {'from': '13.0',
#   'to': '14.25',
#   'visit': 'Cairo Tower',
#   'rating': '4.0',
#   'cost': '0.66'},
#  {'from': '14.25',
#   'to': '14.7',
#   'visit': 'House of the People Beit El-Umma Museum',
#   'rating': '4.5',
#   'cost': '0.66'},
#  {'from': '14.7',
#   'to': '16.7',
#   'visit': 'Abdeen Palace Museum',
#   'rating': '4.0',
#   'cost': '0.66'},
#  {'from': '16.7',
#   'to': '17.7',
#   'visit': 'National Geographic Society Museum',
#   'rating': '4.5',
#   'cost': '0.66'}]

# %%
data = pd.read_csv('museums1.csv')

# %%
data.head()
# Out:
#                                                about  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  This complex comprises an ethnographic museum,...
# 4  This famous museum houses the world’s largest ...
#
#                                              address firstTag  \
# 0  1 El Emam St., | ,El Fustat,, ,Cairo 11511, ,E...  Museums
# 1            Al Fustat Street,, ,Cairo 11511, ,Egypt  Museums
# 2                                      Cairo, ,Egypt  Museums
# 3  Kasr El Aini Street, | ,El Shura Council Compo...  Museums
# 4  Midan El Tahrir, | ,Geographical Society Build...  Museums
#
#                                                image   latitude  longitude  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...  30.007196  31.235327
# 1  https://media-cdn.tripadvisor.com/media/photo-...  30.007747  31.248562
# 2  https://media-cdn.tripadvisor.com/media/photo-...  30.074827  31.306326
# 3  https://media-cdn.tripadvisor.com/media/photo-...  30.033990  31.233440
# 4  https://media-cdn.tripadvisor.com/media/photo-...  30.046997  31.233677
#
#                                             name     overallrate  rate  \
# 0              Foustat Traditional Crafts Center     \n7 reviews   4.5
# 1  National Museum of Egyptian Civilization NEMC      22 reviews   4.0
# 2                           October War Panorama    \n22 reviews   4.0
# 3             National Geographic Society Museum    \n18 reviews   4.5
# 4             The Museum of Egyptian Antiquities  12,037 reviews   4.5
#
#    secondTag  duration(hour)  open  close  price  egyptian and arab  \
# 0        NaN            0.45     9     18   12.0               1.33
# 1        NaN            2.00     9     17   17.0               1.33
# 2        NaN            1.50     9     17   16.0               1.33
# 3        NaN            1.00     9     17   20.0               1.33
# 4        NaN            1.50     9     17    6.0               1.33
#
#    egyptian and arab student  foreigner  foreigner student         Type  \
# 0                       0.66      13.33               3.33  modern age
# 1                       0.66      13.33               3.33    pharaonic
# 2                       0.66      13.33               3.33  modern age
# 3                       0.66      13.33               3.33      science
# 4                       0.66      13.33               3.33    pharaonic
#
#   Closeoropen
# 0       close
# 1       close
# 2       close
# 3       close
# 4       close

# %%
global_price = 'foreigner'

# %%
def remove_place(full_program, index):
    '''
    Remove a place whose index is `index`
    
    Args:
        program (list of dicts): list of places in a program
        index (int): index of place to be removed
    
    Returns:
        alternate_places (list of dicts): nearest three places to that removed 
    '''
    alternate_places = []
    dist_dict = {}
    num_of_places = 3

    program = full_program['program']
    places_in_program = [program[i]['visit'] for i in range(len(program))]

    ptbr = program[index]['visit']    # name of place to be removes
    start_time = program[index]['from']
    ptbr_lng = float(data[data['name'] == ptbr]['longitude'])
    ptbr_lat = float(data[data['name'] == ptbr]['latitude'])
    
    # Calculate EucDist between this place and all others
    # Save in dict {place: dist}
    for i, row in data.iterrows():
        place = row['name']
        lng = row['longitude']
        lat = row['latitude']

        euc_dist = (((ptbr_lng - lng)**2 + (ptbr_lat - lat)**2)**1/2)*10000
    #     print(f'[DEBUG] Distance between {ptbr} and {place} is {euc_dist}')

        # Remove enteries that are already in the program
        if place not in places_in_program:
            dist_dict[place] = euc_dist
    
    # Sort dict by distance ascendingly
    dist_dict = dict(sorted(dist_dict.items(), key=lambda item: item[1]))
    
    # Get list of first three places
    nearest_places = list(dist_dict.keys())[:num_of_places]
    # print(f'[DEBUG] Nearest places: {nearest_places}')

    # Get info of first three places (from, to, name, rating, cost)
    for nearest_place in nearest_places:
        dicc = {'from': '', 'to': '', 'visit': '',
                'rating': '', 'cost': ''}

        nearest_place_info = data[data['name'] == nearest_place]
        # print(f'[DEBUG] Nearest place info: {nearest_place_info}')
        duration = nearest_place_info['duration(hour)'].values[0]
        rating = nearest_place_info['rate'].values[0]
        cost = nearest_place_info[global_price].values[0]

        dicc['from'] = str(start_time)
        dicc['to'] = str(float(start_time) + float(duration))
        dicc['visit'] = nearest_place
        dicc['rating'] = str(rating)
        dicc['cost'] = str(cost)

        alternate_places.append(dicc)

    # Return dict
    alt_places_dict = {"alternativePlaces": alternate_places}
    return json.dumps(alt_places_dict)

# %%
remove_place(full_program, 3)
# Out:
# '{"alternativePlaces": [{"from": "13.0", "to": "13.45", "visit": "Sami Amin", "rating": "3.0", "cost": "13.33"}, {"from": "13.0", "to": "14.0", "visit": "Manial Palace Museum", "rating": "4.5", "cost": "13.33"}, {"from": "13.0", "to": "14.0", "visit": "German Evangelical Church", "rating": "4.0", "cost": "0.0"}]}'

# %%
# dist_dict = {}
# num_of_places = 3

# places_in_program = [program[i]['you will visit'] for i in range(len(program))]

# ptbr = program[3]['you will visit']
# ptbr_lng = float(data[data['name'] == ptbr]['longitude'])
# ptbr_lat = float(data[data['name'] == ptbr]['latitude'])

# for i, row in data.iterrows():
#     place = row['name']
#     lng = row['longitude']
#     lat = row['latitude']
    
#     euc_dist = (((ptbr_lng - lng)**2 + (ptbr_lat - lat)**2)**1/2)*10000
# #     print(f'Distance between {ptbr} and {place} is {euc_dist}')
    
#     if place not in places_in_program:
#         dist_dict[place] = euc_dist

# # dist_dict

# %%
# float(data[data['name'] == ptbr]['longitude'])

# %%
float(data[data['name'] == ptbr]['latitude'])
# Out:
# 30.045903999999997

# %%
dist_dict = dict(sorted(dist_dict.items(), key=lambda item: item[1]))
nearest_places = list(dist_dict.keys())[:num_of_places]
nearest_places
# Out:
# ['Sami Amin', 'Manial Palace Museum', 'German Evangelical Church']

# %%
start_time = program[3]['From']
start_time
# Out:
# '13.0'

# %%
data['foreigner']
# Out:
# 0     13.33
# 1     13.33
# 2     13.33
# 3     13.33
# 4     13.33
#       ...
# 79     0.00
# 80     0.00
# 81     0.00
# 82     0.00
# 83    13.33
# Name: foreigner, Length: 84, dtype: float64

# %%
data['egyptian and arab']
# Out:
# 0     1.33
# 1     1.33
# 2     1.33
# 3     1.33
# 4     1.33
#       ...
# 79    0.00
# 80    0.00
# 81    0.00
# 82    0.00
# 83    1.33
# Name: egyptian and arab, Length: 84, dtype: float64

# %%
data[data['name'] == 'German Evangelical Church']
# Out:
#    about                                            address  \
# 56   NaN  6 Gaber Ibn Hayyan, | ,Dokki,, ,Cairo 11511, ,...
#
#               firstTag                                              image  \
# 56  Sights & Landmarks  https://static.tacdn.com/img2/brand_refresh/ap...
#
#     latitude  longitude                       name overallrate  rate  \
# 56  30.03195   31.21147  German Evangelical Church    1 review   4.0
#
#     secondTag  duration(hour)  open  close  price  egyptian and arab  \
# 56        NaN             1.0     9     17   11.0                0.0
#
#     egyptian and arab student  foreigner  foreigner student    Type  \
# 56                        0.0        0.0                0.0  coptic
#
#    Closeoropen
# 56        open
